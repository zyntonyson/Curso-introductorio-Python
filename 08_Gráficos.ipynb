# %% [markdown]
# <a href="https://colab.research.google.com/github/zyntonyson/Curso-introductorio-Python/blob/master/08_Gr%C3%A1ficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gráficos en Python

# %% [markdown]
# Matplotlib is a Python 2D plotting library which produces publication-quality figures in a variety of hardcopy formats and interactive environments across platforms.
#
# Cheatsheet:
#
# * https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf
#
# * tutorial:  https://realpython.com/python-matplotlib-guide/#why-can-matplotlib-be-confusing

# %%
  
#permite mostrar el gráfico en el notebook
# %matplotlib inline

# Paquetes necesarios
import matplotlib.pyplot as plt
import numpy as np  
import pandas as pd  
np.random.seed(100)

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax

# %%
x=[1,2,3,4,5]
y=[2,4,6,8,10]
y2=[7,10,13,16,19]
plt.plot(x,y,color='green')

# %%
plt.plot(x,y2)

# %%
plt.plot(x,y)
plt.plot(x,y2)

# %%
plt.plot(x,y,color='red')
plt.show()
plt.plot(x,y2,color='gray')

# %%
x=np.linspace(start = 0, stop = 10, num = 50)
plt.plot(x, np.sin(x), label='sin curve')
plt.plot(x, np.cos(x), label='sin curve')
plt.xlabel('x', fontsize=15, color='green')
plt.ylabel('sin(x)', fontsize=15, color='green')
plt.legend()   # for label
plt.title('Playing with Plots')  # for title
# Out:
# Text(0.5, 1.0, 'Playing with Plots')

# %%
plt.plot(x, np.sin(x), label='sin curve')
plt.xlabel('x', fontsize=15, color='green')
plt.ylabel('sin(x)', fontsize=15, color='green')
plt.legend()   # for label
plt.title('Playing with Plots')  # for title
plt.xlim(1, 5)
plt.ylim(0, 0.5)
# Out:
# (0, 0.5)

# %%
random_array = np.random.randn(20)

# %%
plt.plot(random_array,
        color='green',
        linestyle=':')  # dot style graph

# %%
plt.plot(random_array,
        color='green',
        linestyle='--') # line style

# %%
plt.plot(random_array,
        color='green',
        linestyle='--',
        linewidth=3)

# %%
plt.plot(random_array,
        color='green',
        marker ='d')#type point
plt.plot()

# %%
plt.plot(random_array,
        color='green',
        marker ='o', # diamond shape 
        markersize=10) # changing size of diamond shape

# %%
plt.plot(random_array,
        color='green',
        marker ='x', # diamond shape 
        markersize=10, # changing size of diamond shape
        linestyle='None') # Remove the line show only diamond shape

# %%
datanormal=np.random.normal(0,1,1000)
plt.hist(datanormal,density=True)
plt.ylabel('frequencia')
plt.xlabel('valores')
plt.title('Histograma')
# Out:
# Text(0.5, 1.0, 'Histograma')

# %%
plt.boxplot(datanormal)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7faaca1ade48>],
#  'caps': [<matplotlib.lines.Line2D at 0x7faaca13c710>,
#   <matplotlib.lines.Line2D at 0x7faaca13ca58>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7faaca144128>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7faaca13cda0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7faaca13c080>,
#   <matplotlib.lines.Line2D at 0x7faaca13c3c8>]}

# %%
n = 12
X = np.arange(n)
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)

plt.axes([0.025,0.025,0.95,0.95])
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')

for x,y in zip(X,Y1):
    plt.text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')

for x,y in zip(X,Y2):
    plt.text(x+0.4, -y-0.05, '%.2f' % y, ha='center', va= 'top')

plt.xlim(-.5,n), plt.xticks([])
plt.ylim(-1.25,+1.25), plt.yticks([])

# savefig('../figures/bar_ex.png', dpi=48)
plt.show()

# %% [markdown]
# ##Referencias
#
# * https://www.kaggle.com/grroverpr/matplotlib-plotting-guide
#
# * https://github.com/rougier/matplotlib-tutorial#introduction
